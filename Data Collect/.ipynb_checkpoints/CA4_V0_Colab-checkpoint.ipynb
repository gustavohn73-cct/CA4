# %% [markdown]
# # Requirements

# %%
# !pip install -q internetarchive

# %% [markdown]
# # Imports

# %%
import internetarchive
import os
import tarfile
import csv
from datetime import datetime
from tqdm.notebook import tqdm
import pandas as pd
import configparser
import json

import warnings

# Suppressing the warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Functions

# %% [markdown]
# ## General

# %% [markdown]
# Mount your Google drive, so you can save controls files there and you won't lose it

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# put here the path where you want to save the controls file in your Google Drive after '/content/drive/MyDrive/'

# %%
g_path = '/content/drive/MyDrive/CCT_CA/Files'

# %% [markdown]
# This function will be used for controls files and temp files, so it has an option of put the full path.

# %%
def check_folder(name_folder, complete_path = False):            
    #Creating folder if that doesn't exist
    if complete_path == False:
      p = %pwd
      p = f'{p}/{name_folder}'
    else:
      p = f'{complete_path}/{name_folder}'

    path = os.path.expanduser(p)
    if not os.path.exists(path):
        os.makedirs(path)
        print("{} created.".format(path))
        
    return path

# %%
#This function will get the day (files) inside the month (item)
def get_file_name(item_name, ext='*tar'):
    
    file_names = [f.name for f in internetarchive.get_files(item_name, glob_pattern= ext)]
    
    return file_names

# %%
#This function will convert the size so will be easer ready
def humanize(size_bytes):
    KB = 1 << 10
    MB = 1 << 20
    GB = 1 << 30

    if size_bytes < KB:
        return '{} B'.format(size_bytes)
    elif size_bytes < MB:
        return '{:.2f} KiB'.format(size_bytes/KB)
    elif size_bytes < GB:
        return '{:.2f} MiB'.format(size_bytes/MB)
    else:
        return '{:.2f} GiB'.format(size_bytes/GB)

# %%
#by default for control
def create_csv(file_path, file_name = 'control.csv', fieldnames=['name','datetime', 'type', 'size', 'count_total', 'count_filtered']):
    
    file = f"{file_path}/{file_name}"
    
    #if file doesn't exist I'll create it
    if not os.path.exists(file):
        with open(file, 'w', newline='') as control_csv:
            writer = csv.DictWriter(control_csv, fieldnames = fieldnames)
            writer.writeheader()
        control_csv.close()
        print("{} created.".format(file))
    
    return file

# %%
def read_csv(file_path):
    
    #Reading the control file
    with open(file_path, 'r', newline='') as csv_file:
        reader = csv.DictReader(csv_file)
        reader_data = [r for r in reader]
        csv_file.seek(0)
    csv_file.close()

    return reader_data

# %%
def insert_csv(csv_path, row, fieldnames=['name','datetime', 'type', 'size','count_total', 'count_filtered']):
    
    #openning control file to add file names on the list
    with open(csv_path, 'a', newline='') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames = fieldnames)
        writer.writerow(row)
    csv_file.close()

    return csv_path

# %%
#updating name as default
def update_csv(csv_path, val_filter, col_update, val_update, col_filter = 'name'):
  
  df = pd.read_csv(csv_path)

  df.loc[df[col_filter] == val_filter, col_update] = val_update

  df.to_csv(csv_path, index=False)

  return csv_path

# %%
#this fuction will fiter the data, using a bag of word that you select for your assessment
def filter_data(file_path, file_name, word_bag = False, lang = False, control_path = False, get_col = ['created_at', 'text', 'entities']):
    
    #reading json
    df = pd.read_json(file_path, lines=True, compression='gzip')
    
    #updating total tweets
    if not control_path == False:
      update_csv(csv_path = control_path, val_filter = file_name, col_update = 'count_total', val_update = len(df))
    
    #Filtering language if a language was sent
    if not lang == False:
        df = df[df.lang == lang]
    
    #taking away columns unnecessary
    df = df.loc[:, get_col]
    
    #filtering Tweets using subject word bag if a word bag was sent
    if not word_bag == False:
        bow = '|'.join(word_bag) # bag of word
        df = df[df['text'].str.contains(bow, case=False)]
        
        #updating filtered tweets
        if not control_path == False:
          update_csv(csv_path = control_path, val_filter = file_name, col_update = 'count_filtered', val_update = len(df))
    
    return df

# %%
def download_file_csv(item_name, file_name, download_folder = 'Downloads', control_file = 'Local'):
    
    path = check_folder(download_folder)
    
    if not control_file == 'Local':
      control_path = control_file

    else: 
      #calling function for getting control file
      control_path = create_csv(control_path = path, file_name = '/control_download.csv') 
    
    reader_data = read_csv(control_path)
    
    #Getting Itens names
    item = internetarchive.get_item(item_name)

    #check if the file has been downloaded before
    if not any(row['name'] == file_name for row in reader_data):
        
      #downloading
      r = item.download(
          destdir=path,  # The directory to download files to
          ignore_existing=True,  # Skip files that already exist locally
          checksum=True,  # Skip files based on checksum
          verbose=True,  # Print progress to stdout
          retries=100,  # The number of times to retry on failed requests
          no_directory=True,  # Download withtout the identifier
          files = file_name)
      
      #Adding file name on control list
      #getting Metadata
      metadata = list(filter(lambda p: p["name"] == file_name, item.item_metadata['files']))
      row = {'name':file_name, 'datetime':datetime.now().strftime('%Y-%m-%d %H:%M:%S'),'type':'download', 'size':metadata[0]['size']}
      insert_csv(csv_path = control_path, row = row)
        
      path_file = path + f'/{file_name}'
    
    else:
      path_file = False
    
    return path_file

# %%
def tar_file_csv(tar_file, file_name, extration_folder='Extraction', control_file='Local'):

    path = check_folder(extration_folder)
    
    if not control_file == 'Local':
      control_path = control_file

    else: 
      #calling function for getting control file
      control_path = create_csv(control_path = path, file_name = '/control_extraction.csv') 
    
    reader_data = read_csv(control_path)

    #check if the file has been extrated before
    if not any(row['name'] == file_name for row in reader_data):

        #Extracting file
        tar_file.extract(file_name, path=path)

        #Saving files name on control file
        row = {'name' : file_name, 'datetime': datetime.now().strftime('%Y-%m-%d %H:%M:%S'), 'type' : 'extraction', 'size' : tar_file.getmember(name=file_name).size}
        insert_csv(csv_path = control_path, row = row)
        
        path_file = path + f'/{file_name}'
        
    else:
        
        path_file = False
    
    return path_file

# %% [markdown]
# #Code

# %%
month = '202201'
item_name = 'archiveteam-twitter-stream-2022-01'
tweets_col = ['created_at', 'text', 'entities']

#file control in Google Drive
gdrive_path = check_folder(month, g_path)
control_file = create_csv(gdrive_path)
tweets = create_csv(gdrive_path, file_name = f'{month}_tweets.csv', fieldnames = tweets_col)


#Getting Itens names
file_names = get_file_name(item_name = item_name)#, ext = '*jpg')

x = 0 #for testing 

for dlf in tqdm(file_names, desc='Download progress'):
    
    #downloading the file
    file = download_file_csv(item_name = item_name, file_name = dlf, control_file = control_file)
    
    if not file == False:

        #Open tar file
        tar = tarfile.open(file, "r")

        #Getting json files' names
        tar_file_names = list(filter(lambda t: t.endswith('.json.gz'), tar.getnames()))

        for tf in tqdm(tar_file_names, desc='Unzip progress'):

            #call funcition to extract files
            js = tar_file_csv(tar_file = tar, file_name = tf, control_file = control_file)

            #if the file has already been unzipped that part will be skipped
            if not js == False:

                #Getting, cleaning and storing Data
                bow = ['vaccination', 'vaccines', 'vaccine']
                df = filter_data(file_path = js, file_name = tf, word_bag = bow, lang = 'en', control_path = control_file, get_col = tweets_col)

                if not df.empty:

                    for index, row in df.iterrows():
                       row_d = {'created_at': row['created_at'],'text': row['text'],'entities': json.dumps(row['entities'])}
                       insert_csv(csv_path = tweets, row = row_d, fieldnames=tweets_col)

                #deleting json file after processing
                os.remove(js)

        #closing tar file
        tar.close()

        #removing file downloaded
        os.remove(file)
# Out:
# Download progress:   0%|          | 0/31 [00:00<?, ?it/s]
# archiveteam-twitter-stream-2022-01:
#
#  downloading twitter-stream-20220127.tar:   0%|          | 0.00/2.67G [00:00<?, ?iB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 1.00M/2.67G [00:00<34:00, 1.41MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 2.00M/2.67G [00:00<17:56, 2.66MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 3.00M/2.67G [00:01<15:53, 3.00MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 4.00M/2.67G [00:01<12:28, 3.83MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 5.00M/2.67G [00:01<12:48, 3.72MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 6.00M/2.67G [00:01<10:54, 4.37MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 7.00M/2.67G [00:02<11:37, 4.10MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 8.00M/2.67G [00:02<10:13, 4.66MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 9.00M/2.67G [00:02<11:00, 4.33MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 10.0M/2.67G [00:02<09:54, 4.81MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 11.0M/2.67G [00:03<11:09, 4.27MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 12.0M/2.67G [00:03<09:46, 4.87MiB/s]
#  downloading twitter-stream-20220127.tar:   0%|          | 13.0M/2.67G [00:03<10:48, 4.40MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 14.0M/2.67G [00:03<11:37, 4.09MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 15.0M/2.67G [00:04<12:04, 3.94MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 16.0M/2.67G [00:04<12:25, 3.83MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 17.0M/2.67G [00:04<13:00, 3.65MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 18.0M/2.67G [00:05<15:06, 3.14MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 19.0M/2.67G [00:05<16:49, 2.82MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 20.0M/2.67G [00:06<19:51, 2.39MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 21.0M/2.67G [00:06<20:04, 2.36MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 22.0M/2.67G [00:07<25:58, 1.83MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 23.0M/2.67G [00:08<28:28, 1.67MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 24.0M/2.67G [00:09<33:41, 1.41MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 25.0M/2.67G [00:10<38:13, 1.24MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 26.0M/2.67G [00:11<42:58, 1.10MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 27.0M/2.67G [00:12<45:40, 1.04MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 28.0M/2.67G [00:13<46:40, 1.01MiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 29.0M/2.67G [00:15<50:38, 934kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 30.0M/2.67G [00:16<57:04, 828kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 31.0M/2.67G [00:18<1:00:24, 782kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 32.0M/2.67G [00:19<1:06:06, 715kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 33.0M/2.67G [00:21<1:06:56, 706kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|          | 34.0M/2.67G [00:22<1:07:07, 703kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|▏         | 35.0M/2.67G [00:24<1:09:08, 683kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|▏         | 36.0M/2.67G [00:27<1:24:33, 558kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|▏         | 37.0M/2.67G [00:29<1:33:19, 505kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|▏         | 38.0M/2.67G [00:31<1:33:23, 505kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|▏         | 39.0M/2.67G [00:33<1:24:59, 554kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|▏         | 40.0M/2.67G [00:34<1:13:49, 638kiB/s]
#  downloading twitter-stream-20220127.tar:   1%|▏         | 41.0M/2.67G [00:35<1:05:57, 714kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 42.0M/2.67G [00:36<1:01:58, 760kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 43.0M/2.67G [00:38<1:05:25, 719kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 44.0M/2.67G [00:40<1:11:52, 655kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 45.0M/2.67G [00:42<1:14:37, 630kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 46.0M/2.67G [00:43<1:16:21, 616kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 47.0M/2.67G [00:46<1:23:15, 564kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 48.0M/2.67G [00:50<1:52:25, 418kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 49.0M/2.67G [00:53<2:03:47, 379kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 50.0M/2.67G [00:56<2:03:21, 380kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 51.0M/2.67G [00:58<1:59:34, 392kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 52.0M/2.67G [01:02<2:09:21, 363kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 53.0M/2.67G [01:06<2:25:30, 322kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 54.0M/2.67G [01:10<2:33:28, 305kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 55.0M/2.67G [01:13<2:35:18, 302kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 56.0M/2.67G [01:16<2:26:39, 319kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 57.0M/2.67G [01:19<2:18:36, 338kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 58.0M/2.67G [01:21<2:12:43, 353kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 59.0M/2.67G [01:24<2:08:44, 363kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 60.0M/2.67G [01:26<2:02:03, 383kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 61.0M/2.67G [01:29<1:59:22, 392kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 62.0M/2.67G [01:32<2:09:57, 360kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 63.0M/2.67G [01:36<2:15:03, 346kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 64.0M/2.67G [01:39<2:15:07, 346kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 65.0M/2.67G [01:41<2:06:28, 369kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 66.0M/2.67G [01:43<1:55:06, 405kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 67.0M/2.67G [01:45<1:43:35, 450kiB/s]
#  downloading twitter-stream-20220127.tar:   2%|▏         | 68.0M/2.67G [01:47<1:35:09, 490kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 69.0M/2.67G [01:48<1:32:24, 504kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 70.0M/2.67G [01:50<1:29:35, 520kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 71.0M/2.67G [01:52<1:27:21, 533kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 72.0M/2.67G [01:55<1:32:59, 501kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 73.0M/2.67G [01:57<1:37:19, 478kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 74.0M/2.67G [02:00<1:49:12, 426kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 75.0M/2.67G [02:03<2:00:36, 386kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 76.0M/2.67G [02:07<2:09:19, 359kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 77.0M/2.67G [02:10<2:14:13, 346kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 78.0M/2.67G [02:13<2:07:26, 364kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 79.0M/2.67G [02:14<1:52:56, 411kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 80.0M/2.67G [02:16<1:34:55, 489kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 81.0M/2.67G [02:17<1:26:39, 535kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 82.0M/2.67G [02:19<1:22:47, 560kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 83.0M/2.67G [02:21<1:26:39, 535kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 84.0M/2.67G [02:23<1:28:17, 525kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 85.0M/2.67G [02:25<1:27:26, 530kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 86.0M/2.67G [02:27<1:22:53, 559kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 87.0M/2.67G [02:28<1:13:46, 627kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 88.0M/2.67G [02:29<1:02:26, 741kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 89.0M/2.67G [02:30<55:32, 833kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 90.0M/2.67G [02:31<52:16, 884kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 91.0M/2.67G [02:31<48:41, 949kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 92.0M/2.67G [02:33<49:46, 928kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 93.0M/2.67G [02:34<51:43, 893kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 94.0M/2.67G [02:35<50:43, 910kiB/s]
#  downloading twitter-stream-20220127.tar:   3%|▎         | 95.0M/2.67G [02:36<51:12, 901kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▎         | 96.0M/2.67G [02:37<50:54, 906kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▎         | 97.0M/2.67G [02:38<50:02, 922kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▎         | 98.0M/2.67G [02:40<52:02, 886kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▎         | 99.0M/2.67G [02:42<1:04:02, 719kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▎         | 100M/2.67G [02:44<1:11:04, 648kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▎         | 101M/2.67G [02:46<1:14:22, 619kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▎         | 102M/2.67G [02:47<1:12:24, 636kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 103M/2.67G [02:49<1:15:33, 609kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 104M/2.67G [02:52<1:26:53, 529kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 105M/2.67G [02:54<1:34:52, 485kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 106M/2.67G [02:57<1:44:02, 442kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 107M/2.67G [03:00<1:44:50, 438kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 108M/2.67G [03:02<1:50:21, 416kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 109M/2.67G [03:05<1:55:46, 396kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 110M/2.67G [03:08<1:56:45, 393kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 111M/2.67G [03:11<1:57:05, 392kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 112M/2.67G [03:13<1:54:03, 402kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 113M/2.67G [03:16<1:53:53, 402kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 114M/2.67G [03:19<2:03:44, 370kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 115M/2.67G [03:23<2:13:51, 342kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 116M/2.67G [03:26<2:08:47, 355kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 117M/2.67G [03:28<1:58:16, 387kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 118M/2.67G [03:30<1:50:11, 415kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 119M/2.67G [03:32<1:52:10, 408kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 120M/2.67G [03:35<1:53:26, 403kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 121M/2.67G [03:38<2:01:47, 375kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 122M/2.67G [03:43<2:25:37, 314kiB/s]
#  downloading twitter-stream-20220127.tar:   4%|▍         | 123M/2.67G [03:48<2:48:30, 271kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 124M/2.67G [03:53<2:55:52, 260kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 125M/2.67G [03:55<2:31:48, 301kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 126M/2.67G [03:56<2:08:34, 355kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 127M/2.67G [03:58<1:48:48, 419kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 128M/2.67G [03:59<1:36:08, 474kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 129M/2.67G [04:02<1:45:06, 433kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 130M/2.67G [04:06<1:55:21, 395kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 131M/2.67G [04:09<2:03:23, 369kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 132M/2.67G [04:12<2:09:57, 350kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 133M/2.67G [04:15<2:09:38, 351kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 134M/2.67G [04:18<2:04:04, 366kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 135M/2.67G [04:20<1:53:59, 399kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▍         | 136M/2.67G [04:22<1:48:47, 418kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 137M/2.67G [04:24<1:44:38, 434kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 138M/2.67G [04:26<1:37:22, 466kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 139M/2.67G [04:28<1:28:28, 513kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 140M/2.67G [04:29<1:15:33, 600kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 141M/2.67G [04:29<1:02:50, 722kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 142M/2.67G [04:30<52:43, 860kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 143M/2.67G [04:31<43:36, 1.04MiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 144M/2.67G [04:31<39:15, 1.15MiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 145M/2.67G [04:32<36:38, 1.24MiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 146M/2.67G [04:33<41:37, 1.09MiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 147M/2.67G [04:35<56:32, 800kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 148M/2.67G [04:39<1:27:18, 518kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 149M/2.67G [04:43<1:57:46, 384kiB/s]
#  downloading twitter-stream-20220127.tar:   5%|▌         | 150M/2.67G [04:49<2:28:30, 304kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 151M/2.67G [04:53<2:45:30, 273kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 152M/2.67G [04:59<3:03:10, 246kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 153M/2.67G [05:02<2:56:13, 256kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 154M/2.67G [05:04<2:22:31, 317kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 155M/2.67G [05:05<1:52:27, 401kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 156M/2.67G [05:06<1:30:58, 496kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 157M/2.67G [05:07<1:17:13, 584kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 158M/2.67G [05:08<1:11:14, 632kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 159M/2.67G [05:10<1:13:30, 612kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 160M/2.67G [05:13<1:27:18, 516kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 161M/2.67G [05:17<1:55:40, 389kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 162M/2.67G [05:24<2:45:19, 272kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 163M/2.67G [05:28<2:58:56, 251kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 164M/2.67G [05:34<3:14:16, 231kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 165M/2.67G [05:39<3:17:32, 227kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 166M/2.67G [05:42<3:01:18, 248kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 167M/2.67G [05:44<2:32:08, 295kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 168M/2.67G [05:46<2:16:41, 328kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 169M/2.67G [05:49<2:09:03, 348kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▌         | 170M/2.67G [05:51<1:58:59, 377kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▋         | 171M/2.67G [05:53<1:43:52, 431kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▋         | 172M/2.67G [05:55<1:37:58, 457kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▋         | 173M/2.67G [05:58<1:49:47, 408kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▋         | 174M/2.67G [06:00<1:49:33, 409kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▋         | 175M/2.67G [06:03<1:48:53, 411kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▋         | 176M/2.67G [06:05<1:47:02, 418kiB/s]
#  downloading twitter-stream-20220127.tar:   6%|▋         | 177M/2.67G [06:08<1:45:45, 423kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 178M/2.67G [06:11<1:51:23, 401kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 179M/2.67G [06:15<2:11:55, 339kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 180M/2.67G [06:19<2:21:33, 316kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 181M/2.67G [06:22<2:22:49, 313kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 182M/2.67G [06:25<2:19:10, 321kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 183M/2.67G [06:28<2:15:26, 329kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 184M/2.67G [06:31<2:09:57, 343kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 185M/2.67G [06:34<2:08:38, 347kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 186M/2.67G [06:37<2:03:33, 361kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 187M/2.67G [06:39<1:54:55, 388kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 188M/2.67G [06:41<1:44:02, 428kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 189M/2.67G [06:43<1:39:30, 447kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 190M/2.67G [06:46<1:44:48, 424kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 191M/2.67G [06:49<1:51:09, 400kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 192M/2.67G [06:51<1:52:02, 397kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 193M/2.67G [06:54<1:50:26, 402kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 194M/2.67G [06:57<1:52:18, 395kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 195M/2.67G [06:59<1:52:25, 395kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 196M/2.67G [07:01<1:46:51, 415kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 197M/2.67G [07:03<1:34:12, 471kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 198M/2.67G [07:04<1:18:38, 564kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 199M/2.67G [07:05<1:06:42, 664kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 200M/2.67G [07:06<58:00, 764kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 201M/2.67G [07:07<51:34, 859kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 202M/2.67G [07:07<45:31, 973kiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 203M/2.67G [07:08<41:17, 1.07MiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 204M/2.67G [07:09<42:07, 1.05MiB/s]
#  downloading twitter-stream-20220127.tar:   7%|▋         | 205M/2.67G [07:11<48:25, 913kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 206M/2.67G [07:12<53:02, 833kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 207M/2.67G [07:14<56:06, 788kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 208M/2.67G [07:15<1:01:48, 715kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 209M/2.67G [07:18<1:16:39, 576kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 210M/2.67G [07:21<1:31:14, 484kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 211M/2.67G [07:23<1:33:54, 470kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 212M/2.67G [07:25<1:26:25, 510kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 213M/2.67G [07:27<1:19:16, 556kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 214M/2.67G [07:28<1:11:48, 614kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 215M/2.67G [07:29<1:08:08, 647kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 216M/2.67G [07:31<1:05:28, 673kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 217M/2.67G [07:32<1:07:03, 656kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 218M/2.67G [07:35<1:19:17, 555kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 219M/2.67G [07:38<1:33:45, 469kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 220M/2.67G [07:41<1:38:31, 446kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 221M/2.67G [07:44<1:45:21, 417kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 222M/2.67G [07:46<1:46:34, 412kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 223M/2.67G [07:50<2:09:00, 340kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 224M/2.67G [07:55<2:23:59, 305kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 225M/2.67G [07:58<2:23:05, 307kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 226M/2.67G [08:02<2:31:48, 289kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 227M/2.67G [08:06<2:33:38, 285kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 228M/2.67G [08:08<2:15:33, 323kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 229M/2.67G [08:10<1:55:27, 379kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 230M/2.67G [08:12<1:45:00, 417kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 231M/2.67G [08:14<1:36:53, 452kiB/s]
#  downloading twitter-stream-20220127.tar:   8%|▊         | 232M/2.67G [08:16<1:32:54, 471kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▊         | 233M/2.67G [08:19<1:40:34, 435kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▊         | 234M/2.67G [08:23<2:00:41, 362kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▊         | 235M/2.67G [08:28<2:26:49, 298kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▊         | 236M/2.67G [08:31<2:29:19, 293kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▊         | 237M/2.67G [08:34<2:17:58, 316kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▊         | 238M/2.67G [08:35<1:54:09, 382kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▊         | 239M/2.67G [08:36<1:32:48, 470kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 240M/2.67G [08:37<1:14:15, 587kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 241M/2.67G [08:38<1:02:21, 699kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 242M/2.67G [08:39<56:37, 770kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 243M/2.67G [08:40<51:34, 845kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 244M/2.67G [08:41<49:10, 886kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 245M/2.67G [08:42<48:19, 901kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 246M/2.67G [08:43<45:58, 947kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 247M/2.67G [08:44<45:58, 946kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 248M/2.67G [08:46<48:55, 888kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 249M/2.67G [08:47<52:50, 822kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 250M/2.67G [08:49<56:06, 774kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 251M/2.67G [08:51<1:06:28, 653kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 252M/2.67G [08:53<1:12:55, 595kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 253M/2.67G [08:55<1:14:32, 582kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 254M/2.67G [08:57<1:19:47, 544kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 255M/2.67G [09:00<1:27:10, 497kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 256M/2.67G [09:02<1:27:53, 493kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 257M/2.67G [09:04<1:24:22, 513kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 258M/2.67G [09:06<1:25:16, 508kiB/s]
#  downloading twitter-stream-20220127.tar:   9%|▉         | 259M/2.67G [09:09<1:36:23, 449kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 260M/2.67G [09:12<1:44:50, 413kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 261M/2.67G [09:14<1:42:05, 424kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 262M/2.67G [09:15<1:28:00, 491kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 263M/2.67G [09:16<1:11:59, 600kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 264M/2.67G [09:17<1:00:21, 716kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 265M/2.67G [09:18<56:11, 768kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 266M/2.67G [09:20<58:36, 736kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 267M/2.67G [09:22<1:08:21, 631kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 268M/2.67G [09:24<1:17:13, 558kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 269M/2.67G [09:26<1:19:49, 540kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 270M/2.67G [09:29<1:23:30, 516kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 271M/2.67G [09:31<1:32:29, 466kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 272M/2.67G [09:35<1:46:54, 403kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|▉         | 273M/2.67G [09:39<2:02:30, 351kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 274M/2.67G [09:43<2:12:10, 325kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 275M/2.67G [09:47<2:31:19, 284kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 276M/2.67G [09:50<2:17:41, 312kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 277M/2.67G [09:52<1:57:28, 366kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 278M/2.67G [09:53<1:39:51, 430kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 279M/2.67G [09:54<1:27:06, 493kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 280M/2.67G [09:56<1:19:13, 542kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 281M/2.67G [09:58<1:19:10, 542kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 282M/2.67G [10:00<1:25:46, 500kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 283M/2.67G [10:04<1:46:22, 403kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 284M/2.67G [10:08<2:03:52, 346kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 285M/2.67G [10:12<2:19:41, 307kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 286M/2.67G [10:16<2:23:19, 299kiB/s]
#  downloading twitter-stream-20220127.tar:  10%|█         | 287M/2.67G [10:18<2:05:49, 340kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 288M/2.67G [10:20<1:44:17, 410kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 289M/2.67G [10:21<1:27:50, 487kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 290M/2.67G [10:22<1:15:05, 569kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 291M/2.67G [10:23<1:08:07, 627kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 292M/2.67G [10:25<1:07:19, 634kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 293M/2.67G [10:27<1:11:09, 600kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 294M/2.67G [10:29<1:16:01, 561kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 295M/2.67G [10:31<1:23:17, 512kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 296M/2.67G [10:34<1:32:32, 461kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 297M/2.67G [10:37<1:35:51, 445kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 298M/2.67G [10:40<1:43:08, 413kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 299M/2.67G [10:43<1:51:56, 380kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 300M/2.67G [10:45<1:45:54, 402kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 301M/2.67G [10:47<1:36:09, 442kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 302M/2.67G [10:49<1:30:51, 468kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 303M/2.67G [10:51<1:25:52, 495kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 304M/2.67G [10:53<1:28:29, 480kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 305M/2.67G [10:56<1:32:25, 460kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 306M/2.67G [10:58<1:35:26, 445kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█         | 307M/2.67G [11:01<1:37:36, 435kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█▏        | 308M/2.67G [11:03<1:38:11, 432kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█▏        | 309M/2.67G [11:06<1:40:29, 422kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█▏        | 310M/2.67G [11:08<1:41:05, 419kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█▏        | 311M/2.67G [11:11<1:39:36, 425kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█▏        | 312M/2.67G [11:13<1:40:03, 423kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█▏        | 313M/2.67G [11:16<1:37:31, 434kiB/s]
#  downloading twitter-stream-20220127.tar:  11%|█▏        | 314M/2.67G [11:19<1:44:08, 406kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 315M/2.67G [11:22<1:53:32, 373kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 316M/2.67G [11:25<2:00:54, 350kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 317M/2.67G [11:29<2:04:34, 339kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 318M/2.67G [11:32<2:06:26, 334kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 319M/2.67G [11:35<2:08:04, 330kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 320M/2.67G [11:38<2:08:07, 330kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 321M/2.67G [11:41<2:03:54, 341kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 322M/2.67G [11:43<1:52:55, 374kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 323M/2.67G [11:45<1:34:01, 448kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 324M/2.67G [11:45<1:16:07, 554kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 325M/2.67G [11:46<1:03:52, 660kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 326M/2.67G [11:47<59:02, 713kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 327M/2.67G [11:49<59:24, 709kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 328M/2.67G [11:51<1:03:02, 667kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 329M/2.67G [11:53<1:08:14, 616kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 330M/2.67G [11:55<1:10:18, 598kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 331M/2.67G [11:57<1:13:14, 574kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 332M/2.67G [11:59<1:23:29, 503kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 333M/2.67G [12:02<1:33:19, 450kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 334M/2.67G [12:06<1:45:28, 398kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 335M/2.67G [12:10<2:03:57, 338kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 336M/2.67G [12:13<2:10:34, 321kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 337M/2.67G [12:17<2:11:31, 319kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 338M/2.67G [12:20<2:11:17, 319kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 339M/2.67G [12:23<2:12:54, 315kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 340M/2.67G [12:27<2:12:00, 317kiB/s]
#  downloading twitter-stream-20220127.tar:  12%|█▏        | 341M/2.67G [12:30<2:08:25, 326kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 342M/2.67G [12:32<2:02:01, 343kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 343M/2.67G [12:35<1:56:33, 359kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 344M/2.67G [12:37<1:49:15, 383kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 345M/2.67G [12:40<1:45:10, 397kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 346M/2.67G [12:43<1:51:03, 376kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 347M/2.67G [12:46<1:51:38, 374kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 348M/2.67G [12:49<1:53:41, 367kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 349M/2.67G [12:53<2:12:42, 314kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 350M/2.67G [12:57<2:17:58, 302kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 351M/2.67G [13:01<2:30:35, 277kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 352M/2.67G [13:06<2:35:26, 268kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 353M/2.67G [13:09<2:33:02, 272kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 354M/2.67G [13:12<2:18:59, 299kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 355M/2.67G [13:14<1:58:37, 351kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 356M/2.67G [13:16<1:50:10, 377kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 357M/2.67G [13:20<1:59:04, 349kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 358M/2.67G [13:23<2:05:54, 330kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 359M/2.67G [13:26<2:03:27, 336kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 360M/2.67G [13:31<2:27:06, 282kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 361M/2.67G [13:35<2:28:59, 279kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 362M/2.67G [13:39<2:32:06, 273kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 363M/2.67G [13:44<2:43:00, 254kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 364M/2.67G [13:48<2:46:18, 249kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 365M/2.67G [13:52<2:39:19, 260kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 366M/2.67G [13:56<2:37:24, 263kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 367M/2.67G [13:59<2:26:26, 283kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 368M/2.67G [14:01<2:05:23, 330kiB/s]
#  downloading twitter-stream-20220127.tar:  13%|█▎        | 369M/2.67G [14:02<1:41:50, 406kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▎        | 370M/2.67G [14:04<1:27:52, 470kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▎        | 371M/2.67G [14:05<1:18:26, 527kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▎        | 372M/2.67G [14:07<1:20:16, 515kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▎        | 373M/2.67G [14:10<1:32:24, 447kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▎        | 374M/2.67G [14:14<1:49:19, 378kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▎        | 375M/2.67G [14:17<1:51:38, 370kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▎        | 376M/2.67G [14:20<1:51:36, 369kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 377M/2.67G [14:23<1:59:29, 345kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 378M/2.67G [14:26<1:58:44, 347kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 379M/2.67G [14:29<1:49:26, 376kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 380M/2.67G [14:30<1:38:21, 419kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 381M/2.67G [14:34<1:45:39, 389kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 382M/2.67G [14:37<1:57:46, 349kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 383M/2.67G [14:40<2:00:20, 342kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 384M/2.67G [14:43<1:54:48, 358kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 385M/2.67G [14:47<2:02:20, 336kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 386M/2.67G [14:50<2:01:35, 338kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 387M/2.67G [14:52<1:52:11, 366kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 388M/2.67G [14:56<2:10:43, 314kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 389M/2.67G [15:01<2:20:43, 291kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 390M/2.67G [15:05<2:30:57, 272kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 391M/2.67G [15:09<2:26:41, 279kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 392M/2.67G [15:11<2:06:09, 325kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 393M/2.67G [15:12<1:46:49, 383kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 394M/2.67G [15:15<1:43:09, 397kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 395M/2.67G [15:19<1:59:22, 343kiB/s]
#  downloading twitter-stream-20220127.tar:  14%|█▍        | 396M/2.67G [15:23<2:12:23, 309kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 397M/2.67G [15:26<2:12:45, 308kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 398M/2.67G [15:29<2:09:27, 316kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 399M/2.67G [15:33<2:10:42, 312kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 400M/2.67G [15:36<2:09:42, 315kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 401M/2.67G [15:39<2:04:36, 327kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 402M/2.67G [15:42<2:06:18, 323kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 403M/2.67G [15:45<2:02:44, 332kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 404M/2.67G [15:49<2:05:25, 325kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 405M/2.67G [15:55<2:41:30, 252kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 406M/2.67G [16:00<2:50:21, 239kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 407M/2.67G [16:04<2:51:15, 238kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 408M/2.67G [16:11<3:15:22, 208kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 409M/2.67G [16:13<2:46:09, 245kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▍        | 410M/2.67G [16:16<2:24:49, 281kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 411M/2.67G [16:18<2:09:07, 315kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 412M/2.67G [16:21<1:56:23, 349kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 413M/2.67G [16:23<1:47:23, 378kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 414M/2.67G [16:26<1:53:21, 358kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 415M/2.67G [16:29<1:50:17, 368kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 416M/2.67G [16:31<1:46:29, 381kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 417M/2.67G [16:34<1:48:57, 372kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 418M/2.67G [16:38<2:00:16, 337kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 419M/2.67G [16:42<2:08:25, 315kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 420M/2.67G [16:45<2:03:20, 328kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 421M/2.67G [16:47<1:53:13, 357kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 422M/2.67G [16:50<1:47:27, 376kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 423M/2.67G [16:52<1:44:29, 387kiB/s]
#  downloading twitter-stream-20220127.tar:  15%|█▌        | 424M/2.67G [16:56<1:54:27, 353kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 425M/2.67G [16:59<2:03:44, 326kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 426M/2.67G [17:03<2:04:35, 324kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 427M/2.67G [17:06<2:01:44, 331kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 428M/2.67G [17:09<1:57:34, 343kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 429M/2.67G [17:11<1:53:13, 356kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 430M/2.67G [17:15<1:58:41, 339kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 431M/2.67G [17:17<1:55:39, 348kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 432M/2.67G [17:19<1:43:21, 390kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 433M/2.67G [17:21<1:28:44, 453kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 434M/2.67G [17:22<1:17:02, 522kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 435M/2.67G [17:23<1:07:19, 597kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 436M/2.67G [17:24<1:00:25, 665kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 437M/2.67G [17:26<55:24, 725kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 438M/2.67G [17:27<55:07, 728kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 439M/2.67G [17:30<1:08:02, 590kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 440M/2.67G [17:32<1:19:20, 506kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 441M/2.67G [17:35<1:22:52, 484kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 442M/2.67G [17:37<1:24:19, 475kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 443M/2.67G [17:39<1:23:25, 480kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▌        | 444M/2.67G [17:41<1:20:33, 497kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▋        | 445M/2.67G [17:43<1:12:54, 549kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▋        | 446M/2.67G [17:44<1:02:56, 636kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▋        | 447M/2.67G [17:45<56:04, 713kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▋        | 448M/2.67G [17:46<50:31, 791kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▋        | 449M/2.67G [17:47<49:12, 812kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▋        | 450M/2.67G [17:48<47:14, 845kiB/s]
#  downloading twitter-stream-20220127.tar:  16%|█▋        | 451M/2.67G [17:49<45:23, 879kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 452M/2.67G [17:50<43:48, 911kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 453M/2.67G [17:52<47:36, 838kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 454M/2.67G [17:53<50:22, 792kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 455M/2.67G [17:55<52:13, 763kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 456M/2.67G [17:56<54:10, 735kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 457M/2.67G [17:58<59:11, 673kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 458M/2.67G [18:00<1:01:47, 644kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 459M/2.67G [18:02<1:06:57, 594kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 460M/2.67G [18:04<1:07:57, 585kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 461M/2.67G [18:06<1:11:16, 558kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 462M/2.67G [18:08<1:11:11, 558kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 463M/2.67G [18:10<1:13:37, 539kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 464M/2.67G [18:13<1:23:33, 475kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 465M/2.67G [18:16<1:37:27, 407kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 466M/2.67G [18:19<1:40:08, 396kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 467M/2.67G [18:21<1:38:36, 402kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 468M/2.67G [18:24<1:33:18, 425kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 469M/2.67G [18:26<1:35:44, 414kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 470M/2.67G [18:29<1:39:56, 396kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 471M/2.67G [18:31<1:35:59, 412kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 472M/2.67G [18:33<1:28:20, 448kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 473M/2.67G [18:36<1:27:51, 450kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 474M/2.67G [18:38<1:26:44, 456kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 475M/2.67G [18:40<1:25:11, 464kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 476M/2.67G [18:42<1:20:35, 490kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 477M/2.67G [18:44<1:20:31, 490kiB/s]
#  downloading twitter-stream-20220127.tar:  17%|█▋        | 478M/2.67G [18:46<1:21:56, 481kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 479M/2.67G [18:48<1:20:51, 488kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 480M/2.67G [18:51<1:27:38, 450kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 481M/2.67G [18:54<1:34:07, 419kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 482M/2.67G [18:57<1:39:02, 398kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 483M/2.67G [19:00<1:45:43, 372kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 484M/2.67G [19:03<1:49:39, 359kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 485M/2.67G [19:06<1:51:00, 354kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 486M/2.67G [19:09<1:48:45, 361kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 487M/2.67G [19:12<1:47:30, 366kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 488M/2.67G [19:15<1:49:07, 360kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 489M/2.67G [19:19<1:58:09, 332kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 490M/2.67G [19:22<1:59:08, 329kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 491M/2.67G [19:25<1:56:47, 336kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 492M/2.67G [19:28<1:51:50, 351kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 493M/2.67G [19:30<1:46:36, 368kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 494M/2.67G [19:32<1:40:34, 390kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 495M/2.67G [19:36<1:44:36, 374kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 496M/2.67G [19:39<1:49:54, 356kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 497M/2.67G [19:42<1:55:13, 340kiB/s]
#  downloading twitter-stream-20220127.tar:  18%|█▊        | 498M/2.67G [19:45<1:54:03, 343kiB/s]
# ...
#  downloading twitter-stream-20220128.tar:  75%|███████▌  | 1.93G/2.56G [1:04:52<14:43, 764kiB/s]
#  downloading twitter-stream-20220128.tar:  75%|███████▌  | 1.93G/2.56G [1:04:54<15:32, 723kiB/s]
#  downloading twitter-stream-20220128.tar:  75%|███████▌  | 1.93G/2.56G [1:04:56<17:51, 628kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.93G/2.56G [1:04:59<24:10, 464kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.93G/2.56G [1:05:02<26:31, 422kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.93G/2.56G [1:05:05<27:05, 412kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:08<27:01, 413kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:10<26:22, 422kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:12<25:40, 433kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:14<24:54, 446kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:17<23:51, 465kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:19<23:34, 470kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:21<22:46, 485kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:23<22:47, 484kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:26<24:16, 454kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.94G/2.56G [1:05:28<25:15, 436kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.95G/2.56G [1:05:31<26:04, 421kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.95G/2.56G [1:05:33<25:42, 427kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.95G/2.56G [1:05:35<24:39, 444kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.95G/2.56G [1:05:37<23:08, 472kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.95G/2.56G [1:05:39<21:17, 513kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▌  | 1.95G/2.56G [1:05:41<20:36, 529kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▋  | 1.95G/2.56G [1:05:42<19:48, 549kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▋  | 1.95G/2.56G [1:05:44<19:13, 565kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▋  | 1.95G/2.56G [1:05:46<18:23, 589kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▋  | 1.95G/2.56G [1:05:47<17:46, 609kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▋  | 1.96G/2.56G [1:05:50<19:34, 552kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▋  | 1.96G/2.56G [1:05:53<22:47, 473kiB/s]
#  downloading twitter-stream-20220128.tar:  76%|███████▋  | 1.96G/2.56G [1:05:56<24:46, 435kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:05:58<25:45, 418kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:06:01<27:19, 393kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:06:05<29:08, 368kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:06:07<27:56, 383kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:06:08<23:55, 446kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:06:09<19:36, 544kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:06:10<15:49, 673kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.96G/2.56G [1:06:11<13:11, 806kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:12<11:29, 924kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:13<11:47, 898kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:14<11:49, 895kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:16<13:41, 771kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:18<15:25, 683kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:20<17:37, 597kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:23<21:00, 500kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:26<24:40, 425kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:30<28:25, 368kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.97G/2.56G [1:06:33<28:57, 361kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:36<29:50, 350kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:39<28:24, 367kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:41<25:28, 409kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:42<22:30, 461kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:44<22:05, 469kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:47<24:08, 429kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:50<24:49, 416kiB/s]
#  downloading twitter-stream-20220128.tar:  77%|███████▋  | 1.98G/2.56G [1:06:52<24:35, 419kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.98G/2.56G [1:06:54<22:42, 454kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.98G/2.56G [1:06:56<19:54, 516kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:06:57<19:10, 535kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:06:59<18:38, 550kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:01<19:13, 532kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:05<22:34, 452kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:08<26:40, 382kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:11<27:33, 369kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:14<27:14, 373kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:16<25:25, 399kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:18<21:57, 461kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 1.99G/2.56G [1:07:19<19:47, 511kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:21<18:51, 535kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:23<18:02, 558kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:26<21:54, 459kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:29<23:27, 428kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:31<22:46, 440kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:32<19:45, 506kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:34<17:14, 579kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:35<15:26, 645kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:36<14:36, 681kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:37<14:08, 702kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.00G/2.56G [1:07:39<15:14, 650kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.01G/2.56G [1:07:41<15:44, 629kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.01G/2.56G [1:07:43<16:28, 600kiB/s]
#  downloading twitter-stream-20220128.tar:  78%|███████▊  | 2.01G/2.56G [1:07:45<17:09, 575kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▊  | 2.01G/2.56G [1:07:47<18:13, 540kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▊  | 2.01G/2.56G [1:07:50<20:21, 483kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▊  | 2.01G/2.56G [1:07:52<20:42, 474kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▊  | 2.01G/2.56G [1:07:54<19:35, 500kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▊  | 2.01G/2.56G [1:07:55<17:01, 574kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▊  | 2.01G/2.56G [1:07:56<14:15, 684kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▊  | 2.01G/2.56G [1:07:57<11:46, 827kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:07:57<09:44, 998kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:07:58<08:03, 1.20MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:07:58<06:51, 1.41MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:07:59<06:27, 1.50MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:07:59<06:10, 1.56MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:08:00<06:20, 1.52MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:08:01<06:30, 1.48MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:08:02<07:01, 1.37MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:08:03<07:45, 1.23MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.02G/2.56G [1:08:04<09:15, 1.03MiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:06<12:24, 769kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:08<14:02, 678kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:10<15:09, 628kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:13<18:30, 513kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:17<21:52, 433kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:21<28:19, 334kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:26<32:41, 289kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:31<34:54, 270kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:35<35:37, 264kiB/s]
#  downloading twitter-stream-20220128.tar:  79%|███████▉  | 2.03G/2.56G [1:08:38<33:54, 277kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:40<29:40, 316kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:42<24:06, 388kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:43<19:27, 480kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:44<16:09, 577kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:45<13:40, 680kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:46<12:20, 752kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:47<11:23, 814kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:48<10:43, 863kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:49<10:39, 866kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:50<10:12, 903kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.04G/2.56G [1:08:51<09:49, 936kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.05G/2.56G [1:08:52<09:25, 974kiB/s]
#  downloading twitter-stream-20220128.tar:  80%|███████▉  | 2.05G/2.56G [1:08:53<09:09, 1.00MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:54<08:54, 1.03MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:55<08:45, 1.04MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:56<08:24, 1.08MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:56<07:53, 1.15MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:57<07:22, 1.23MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:58<06:43, 1.35MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:58<06:14, 1.45MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.05G/2.56G [1:08:59<06:43, 1.34MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.06G/2.56G [1:09:00<07:08, 1.26MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.06G/2.56G [1:09:01<07:09, 1.26MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.06G/2.56G [1:09:02<07:25, 1.21MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.06G/2.56G [1:09:03<07:53, 1.13MiB/s]
#  downloading twitter-stream-20220128.tar:  80%|████████  | 2.06G/2.56G [1:09:05<09:27, 944kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.06G/2.56G [1:09:06<10:37, 839kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.06G/2.56G [1:09:08<12:10, 731kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.06G/2.56G [1:09:10<14:32, 611kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.06G/2.56G [1:09:13<15:39, 566kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.06G/2.56G [1:09:15<16:35, 533kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:17<16:31, 535kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:19<16:23, 538kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:20<15:18, 575kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:21<13:34, 646kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:22<11:32, 759kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:23<09:45, 896kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:24<08:18, 1.05MiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:24<07:28, 1.16MiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:25<07:15, 1.20MiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.07G/2.56G [1:09:26<07:06, 1.22MiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.08G/2.56G [1:09:27<07:33, 1.15MiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.08G/2.56G [1:09:28<08:01, 1.08MiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.08G/2.56G [1:09:29<08:43, 988kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████  | 2.08G/2.56G [1:09:30<08:52, 970kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████▏ | 2.08G/2.56G [1:09:32<09:39, 889kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████▏ | 2.08G/2.56G [1:09:33<09:47, 875kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████▏ | 2.08G/2.56G [1:09:34<10:00, 854kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████▏ | 2.08G/2.56G [1:09:36<10:15, 832kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████▏ | 2.08G/2.56G [1:09:37<10:04, 845kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████▏ | 2.08G/2.56G [1:09:39<11:24, 745kiB/s]
#  downloading twitter-stream-20220128.tar:  81%|████████▏ | 2.08G/2.56G [1:09:41<14:06, 601kiB/s]
#  downloading twitter-stream-20220128.tar:  82%|████████▏ | 2.09G/2.56G [1:09:43<15:17, 553kiB/s]
#  downloading twitter-stream-20220128.tar:  82%|████████▏ | 2.09G/2.56G [1:09:46<15:48, 534kiB/s]
#  downloading twitter-stream-20220128.tar:  82%|████████▏ | 2.09G/2.56G [1:09:48<15:45, 535kiB/s]
#  downloading twitter-stream-20220128.tar:  82%|████████▏ | 2.09G/2.56G [1:09:49<15:30, 542kiB/s]
